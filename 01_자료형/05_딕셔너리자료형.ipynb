# %%
# 딕셔너리는 어떻게 만들까? 
# {key1 : value1, key2: value2, ...}

dict = {
    "name": "kim", 
    "phone": "010-1234-1234", 
    "birth": "09-02"
}

type(dict)
# Out:
# dict

# %%
## 딕셔너리 쌍 추가하기 
a = {1: "a"}
a[2] = "b"

print(a)
# Out:
# {1: 'a', 2: 'b'}

# %%
a["name"] = "홍길동"
print(a)
# Out:
# {1: 'a', 2: 'b', 'name': '홍길동'}

# %%
a[3] = [1, 2, 3]
print(a)
# Out:
# {1: 'a', 2: 'b', 'name': '홍길동', 3: [1, 2, 3]}

# %%
a = {
    1: "a", 
    2: "b", 
    "name": "홍길동", 
    3: [1, 2, 3], 
    (1, 2): (1, 2), 
    # [1, 2]: [1, 2]
}

a = 1
a = 3

print(a)
# Out:
# 3

# %%
## 딕셔너리에서 key를 사용해서 value값 얻기
학점 = {
    "홍길동": 10, 
    "유재석": 90
}

print(학점["유재석"])
print(학점["홍길동"])

학점["홍길동"] = 80
학점["강호동"] = 70
print(학점)
# Out:
# 90
# 10
# {'홍길동': 80, '유재석': 90, '강호동': 70}

# %%
## 딕셔너리 관련 함수 
## key리스트 만들기 - keys()
dict = {
    "name": "kim", 
    "phone": "010-1234-1234", 
    "birth": "09-02"
}
dict.keys()
list(dict.keys())
# Out:
# ['name', 'phone', 'birth']

# %%
## value 리스트만들기 - values()
dict = {
    "name": "kim", 
    "phone": "010-1234-1234", 
    "birth": "09-02"
}
dict.values()
list(dict.values())
# Out:
# ['kim', '010-1234-1234', '09-02']

# %%
## Key, value 쌍 얻기 - items
dict = {
    "name": "kim", 
    "phone": "010-1234-1234", 
    "birth": "09-02"
}
dict.items()
list(dict.items())
# Out:
# [('name', 'kim'), ('phone', '010-1234-1234'), ('birth', '09-02')]

# %%
## key, Value 쌍 모두 지우기 - clear
dict = {
    "name": "kim", 
    "phone": "010-1234-1234", 
    "birth": "09-02"
}
print(dict)
dict.clear()
print(dict)
# Out:
# {'name': 'kim', 'phone': '010-1234-1234', 'birth': '09-02'}
# {}

# %%
## key로 value값 얻기 - get
dict = {
    "name": "kim", 
    "phone": "010-1234-1234", 
    "birth": "09-02"
}
dict.get("name")
# dict["name"]

dict.get("hobby")
dict["hobby"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 11
#       7 dict.get("name")
#       8 # dict["name"]
#       9
#      10 dict.get("hobby")
# ---> 11 dict["hobby"]
#
# KeyError: 'hobby'
