# %%
# 튜플은 어떻게 만들까? 

t1 = ()
t2 = (1,)
t3 = (1, 2, 3)
t4 = 1, 2, 3
t5 = ("a", "b", ("ab", "cd"))
t6 = tuple()

type(t3)
# Out:
# tuple

# %%
t1 = (10, )
t2 = 10,

print(type(t1))
print(type(t2))

d1 = (10) # d1 = 10

d1 = 10

type(d1)

num = 10, 20

type(num)
# Out:
# <class 'tuple'>
# <class 'tuple'>
# tuple

# %%
## 튜플의 요소값을 지우거나 변경하려고 하면? 
t1 = (1, 2, "a", "b")
del t1[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 ## 튜플의 요소값을 지우거나 변경하려고 하면?
#       2 t1 = (1, 2, "a", "b")
# ----> 3 del t1[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t1 = (1, 2, "a", "b")
t1[2] = "c"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 t1 = (1, 2, "a", "b")
# ----> 2 t1[2] = "c"
#
# TypeError: 'tuple' object does not support item assignment

# %%
## 튜플인덱싱
t1 = (1, 2, "a", "b")
print(t1[0])
print(t1[-1])
# Out:
# 1
# b

# %%
## 슬라이싱
t1 = (1, 2, "a", "b")
t1[1:]
# Out:
# (2, 'a', 'b')

# %%
## 튜플더하기
t1 = (1, 2, "a", "b")
t2 = (3, 4)
print(t1 + t2)
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
t2 = (3, 4)
t2 * 3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
t1 = (1, 2, "a", "b")
len(t1)
# Out:
# 4
